# %% [markdown]
# # Evaluation Project on Avocado Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Avocado.csv')
data
# Out:
#           Date  AveragePrice  Total Volume        4046        4225       4770  \
# 0   27-12-2015          1.33      64236.62     1036.74    54454.85      48.16
# 1   20-12-2015          1.35      54876.98      674.28    44638.81      58.33
# 2   13-12-2015          0.93     118220.22      794.70   109149.67     130.50
# 3   06-12-2015          1.08      78992.15     1132.00    71976.41      72.58
# 4   29-11-2015          1.28      51039.60      941.48    43838.39      75.78
# ..         ...           ...           ...         ...         ...        ...
# 26  28-06-2015          1.10    5641742.02  3163839.74  1610910.07  212173.21
# 27  21-06-2015          1.07    5952597.29  3328631.93  1743509.25  218423.77
# 28  14-06-2015          0.97    6741662.31  4075881.34  1771908.98  210670.82
# 29  07-06-2015          0.98    6374842.90  3614314.44  1860329.30  221330.48
# 30  31-05-2015          0.98    6236903.31  3620440.35  1826496.62  209443.33
#
# ...

# %%
data.head(10)
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
# 5          1.26      55979.78  1184.27   48067.99   43.61     6683.91
# 6          0.99      83453.76  1368.92   73672.72   93.26     8318.86
# 7          0.98     109428.33   703.75  101815.36   80.00     6829.22
# 8          1.02      99811.42  1022.15   87315.57   85.34    11388.36
# 9          1.07      74338.76   842.40   64757.44  113.00     8625.92
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8603.62       93.25          0.0  conventional  2015  Albany
# ...

# %%
data.tail(5)
# Out:
#     AveragePrice  Total Volume        4046        4225       4770  Total Bags  \
# 26          1.10    5641742.02  3163839.74  1610910.07  212173.21   654819.00
# 27          1.07    5952597.29  3328631.93  1743509.25  218423.77   662032.34
# 28          0.97    6741662.31  4075881.34  1771908.98  210670.82   683201.17
# 29          0.98    6374842.90  3614314.44  1860329.30  221330.48   678868.68
# 30          0.98    6236903.31  3620440.35  1826496.62  209443.33   580523.01
#
#     Small Bags  Large Bags  XLarge Bags          type  year      region
# 26   630301.44    21861.54      2656.02  conventional  2015  California
# 27   634244.68    24277.53      3510.13  conventional  2015  California
# 28   657421.42    22961.19      2818.56  conventional  2015  California
# 29   651944.51    23422.39      3501.78  conventional  2015  California
# 30   554224.64    23083.08      3215.29  conventional  2015  California

# %% [markdown]
# # Preprocessing

# %%
# Let's check the null value
data.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
# Let's check the datatypes of the columns
data.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
# Let's describe the data
data.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225           4770  \
# count    199.000000  1.990000e+02  1.990000e+02  1.990000e+02     199.000000
# mean       1.134724  7.618776e+05  3.260171e+05  2.975311e+05   26080.891508
# std        0.113324  1.489716e+06  8.382285e+05  4.791732e+05   56295.383737
# min        0.930000  4.050736e+04  5.099400e+02  4.856270e+03      21.500000
# 25%        1.060000  8.230342e+04  1.420775e+03  3.159033e+04     153.100000
# 50%        1.120000  3.861005e+05  5.115127e+04  6.793379e+04     911.250000
# 75%        1.200000  6.513507e+05  2.511078e+05  4.044447e+05   31875.390000
# max        1.450000  6.741662e+06  4.075881e+06  2.196705e+06  254187.470000
#
#           Total Bags     Small Bags    Large Bags  XLarge Bags    year
# count     199.000000     199.000000    199.000000   199.000000   199.0
# mean   112248.500251  105562.896884   6422.862915   262.740452  2015.0
# ...

# %%
data.drop(data.columns[0],axis=1,inplace=True)

# %%
data
# Out:
#     AveragePrice  Total Volume        4046        4225       4770  Total Bags  \
# 0           1.33      64236.62     1036.74    54454.85      48.16     8696.87
# 1           1.35      54876.98      674.28    44638.81      58.33     9505.56
# 2           0.93     118220.22      794.70   109149.67     130.50     8145.35
# 3           1.08      78992.15     1132.00    71976.41      72.58     5811.16
# 4           1.28      51039.60      941.48    43838.39      75.78     6183.95
# ..           ...           ...         ...         ...        ...         ...
# 26          1.10    5641742.02  3163839.74  1610910.07  212173.21   654819.00
# 27          1.07    5952597.29  3328631.93  1743509.25  218423.77   662032.34
# 28          0.97    6741662.31  4075881.34  1771908.98  210670.82   683201.17
# 29          0.98    6374842.90  3614314.44  1860329.30  221330.48   678868.68
# 30          0.98    6236903.31  3620440.35  1826496.62  209443.33   580523.01
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 0 to 30
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  199 non-null    float64
#  1   Total Volume  199 non-null    float64
#  2   4046          199 non-null    float64
#  3   4225          199 non-null    float64
#  4   4770          199 non-null    float64
#  5   Total Bags    199 non-null    float64
#  6   Small Bags    199 non-null    float64
#  7   Large Bags    199 non-null    float64
#  8   XLarge Bags   199 non-null    float64
#  9   type          199 non-null    object
#  10  year          199 non-null    int64
#  11  region        199 non-null    object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 20.2+ KB

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(20,10))

for i in range(len(data.columns)):
    if data.dtypes[i] !='object':
        plt.subplot(3,5,i+1)
        plt.boxplot(data[data.columns[i]], vert=False)
        plt.title(data.columns[i])
        
plt.show()

# %%
# Let's check the skewness of the dataset
data.skew()
# Out:
# AveragePrice    0.421211
# Total Volume    3.096425
# 4046            3.204344
# 4225            2.491693
# 4770            2.783006
# Total Bags      2.458991
# Small Bags      2.438725
# Large Bags      2.122419
# XLarge Bags     3.369808
# year            0.000000
# dtype: float64

# %%
# Let's check the correlation matrix
data.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.125268 -0.189358 -0.038095 -0.065088
# Total Volume     -0.125268      1.000000  0.977698  0.958605  0.970167
# 4046             -0.189358      0.977698  1.000000  0.878630  0.918492
# 4225             -0.038095      0.958605  0.878630  1.000000  0.964957
# 4770             -0.065088      0.970167  0.918492  0.964957  1.000000
# Total Bags       -0.036903      0.965576  0.899531  0.976904  0.968438
# Small Bags       -0.011045      0.961408  0.890154  0.980765  0.969864
# Large Bags       -0.420541      0.352814  0.412024  0.232830  0.266363
# XLarge Bags      -0.103602      0.966003  0.956912  0.911627  0.939178
# year                   NaN           NaN       NaN       NaN       NaN
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags  year
# AveragePrice   -0.036903   -0.011045   -0.420541    -0.103602   NaN
# ...

# %%
import seaborn as sns
sns.pairplot(data)
plt.show()

# %%
sns.heatmap(data.isnull())
plt.show()
# Therefore it is clear that there are no null values
